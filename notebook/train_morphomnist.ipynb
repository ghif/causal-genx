# %%
# !nvidia-smi

# %%
# Connect to gdrive
from google.colab import drive
drive.mount('/content/drive')

# %%
from google.colab import auth
auth.authenticate_user()

print('Authenticated successfully')

# %%
# %cd /content/drive/MyDrive/Colab\ Notebooks
# !pwd

# %%
# !git clone https://github.com/ghif/causal-genx.git

# %%
# %cd causal-genx

# %%
# %cd causal-genx
# !pwd

# %%
# !git fetch origin

# %%
# !git reset --hard origin/main

# %%
# !git pull origin main

# %%
# %cd src

# %%
# !python -u main.py \
  --accelerator=gpu \
  --precision=bf16 \
  --exp_name=jax-gpu-a100 \
  --data_dir=gs://medical-airnd/causal-gen/datasets/morphomnist \
  --ckpt_dir=../checkpoints \
  --remote_ckpt_dir=gs://medical-airnd/causal-gen/checkpoints \
  --hps morphomnist \
  --parents_x thickness intensity digit \
  --context_dim=12 \
  --concat_pa \
  --lr=0.001 \
  --bs=128 \
  --wd=0.01 \
  --beta=1 \
  --cond_prior \
  --viz_freq=1 \
  --viz_batch_size=32 \
  --eval_freq=4

# %%
# !python -u main.py \
  --accelerator=tpu \
  --precision=bf16 \
  --exp_name=jax-tpu-v6e-1_11-07-2026 \
  --data_dir=gs://medical-airnd/causal-gen/datasets/morphomnist \
  --ckpt_dir=../checkpoints \
  --remote_ckpt_dir=gs://medical-airnd/causal-gen/checkpoints \
  --hps morphomnist \
  --parents_x thickness intensity digit \
  --context_dim=12 \
  --concat_pa \
  --lr=0.001 \
  --bs=128 \
  --wd=0.01 \
  --beta=1 \
  --cond_prior \
  --viz_freq=50 \
  --viz_batch_size=32 \
  --eval_freq=50 \

# %%
# !pip install tensorboard 
# !pip install gcsfs

# %%
# !ls
